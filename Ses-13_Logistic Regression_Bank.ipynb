# %%
import pandas as pd
data = pd.read_excel("Datasets//german bank data.xlsx", sheet_name = "german bank data")
display(data)
# Out:
#       S.No  age            job   marital  education default  balance housing  \
# 0        1   59     unemployed   married    primary      no        0      no
# 1        2   36         Others   married   tertiary      no     3057      no
# 2        3   47    blue-collar  divorced    primary      no      126     yes
# 3        4   43     management  divorced   tertiary      no      388     yes
# 4        5   34  self-employed    single   tertiary      no      462      no
# ...    ...  ...            ...       ...        ...     ...      ...     ...
# 4516  4517   58    blue-collar   married    primary      no        0     yes
# 4517  4518   38         Others   married    primary      no        0     yes
# 4518  4519   53  self-employed   married   tertiary      no     2627     yes
# 4519  4520   49    blue-collar   married    primary      no      371     yes
# 4520  4521   35    blue-collar   married  secondary      no      280     yes
#
#      loan  campaign    y  SubscriptionY
# ...

# %%
# Converting categorical variables into dummy variables...
data = pd.get_dummies(data, columns=["job", "marital", "education", "default", "housing", "loan"], drop_first=True)
list(data.columns)
# Out:
# ['S.No',
#  'age',
#  'balance',
#  'campaign',
#  'y',
#  'SubscriptionY',
#  'job_blue-collar',
#  'job_management',
#  'job_self-employed',
#  'job_unemployed',
#  'marital_married',
#  'marital_single',
#  'education_secondary',
#  'education_tertiary',
#  'education_unknown',
#  'default_yes',
#  'housing_yes',
#  'loan_yes']

# %%
display(data)
# Out:
#       S.No  age  balance  campaign    y  SubscriptionY  job_blue-collar  \
# 0        1   59        0         2   no              0                0
# 1        2   36     3057         4  yes              1                0
# 2        3   47      126         2  yes              1                1
# 3        4   43      388         2  yes              1                0
# 4        5   34      462         3  yes              1                0
# ...    ...  ...      ...       ...  ...            ...              ...
# 4516  4517   58        0        25   no              0                1
# 4517  4518   38        0        32   no              0                0
# 4518  4519   53     2627        30   no              0                0
# 4519  4520   49      371        44   no              0                1
# 4520  4521   35      280        50   no              0                1
#
#       job_management  job_self-employed  job_unemployed  marital_married  \
# ...

# %%
# Defining variables...

#X = pd.DataFrame(data[['age']])
#X = pd.DataFrame(data[['marital_married', 'marital_single']])
#X = pd.DataFrame(data[['education_secondary', 'education_tertiary', 'education_unknown']])
#X = pd.DataFrame(data[['job_blue-collar', 'job_management', 'job_self-employed', 'job_unemployed']])
X = pd.DataFrame(data[['age', 'balance', 'job_blue-collar', 'job_management', 'job_self-employed', 'job_unemployed', 'marital_married', 'marital_single', 'education_secondary', 'education_tertiary', 'education_unknown', 'default_yes', 'housing_yes']])

y = pd.DataFrame(data[['SubscriptionY']])

# %%
display(X.head())
display(y.head())
# Out:
#    age  balance  job_blue-collar  job_management  job_self-employed  \
# 0   59        0                0               0                  0
# 1   36     3057                0               0                  0
# 2   47      126                1               0                  0
# 3   43      388                0               1                  0
# 4   34      462                0               0                  1
#
#    job_unemployed  marital_married  marital_single  education_secondary  \
# 0               1                1               0                    0
# 1               0                1               0                    0
# 2               0                0               0                    0
# 3               0                0               0                    0
# 4               0                0               1                    0
#
#    education_tertiary  education_unknown  default_yes  housing_yes
# ...

# %%
# Logistic Regression Model-1...

import statsmodels.api as sm

X = sm.add_constant(X)

model = sm.Logit(y, X)
result = model.fit(method='newton')

# Evaluate Model...

display(result.summary())
display(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.347117
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:          SubscriptionY   No. Observations:                 4521
# Model:                          Logit   Df Residuals:                     4507
# Method:                           MLE   Df Model:                           13
# Date:                Wed, 30 Nov 2022   Pseudo R-squ.:                 0.02859
# Time:                        11:25:04   Log-Likelihood:                -1569.3
# converged:                       True   LL-Null:                       -1615.5
# Covariance Type:            nonrobust   LLR p-value:                 4.911e-14
# ...
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
# Removing Balance as it is insignificant...

X = pd.DataFrame(data[['age', 'job_blue-collar', 'job_management', 'job_self-employed', 'job_unemployed', 'marital_married', 'marital_single', 'education_secondary', 'education_tertiary', 'education_unknown', 'default_yes', 'housing_yes']])

y = pd.DataFrame(data[['SubscriptionY']])

display(X.head())
display(y.head())
# Out:
#    age  job_blue-collar  job_management  job_self-employed  job_unemployed  \
# 0   59                0               0                  0               1
# 1   36                0               0                  0               0
# 2   47                1               0                  0               0
# 3   43                0               1                  0               0
# 4   34                0               0                  1               0
#
#    marital_married  marital_single  education_secondary  education_tertiary  \
# 0                1               0                    0                   0
# 1                1               0                    0                   1
# 2                0               0                    0                   0
# 3                0               0                    0                   1
# 4                0               1                    0                   1
#
#    education_unknown  default_yes  housing_yes
# ...

# %%
# Logistic Regression Model-2...
X = sm.add_constant(X)

model = sm.Logit(y, X)
result = model.fit(method='newton')

# Evaluate Model...

display(result.summary())
display(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.347134
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:          SubscriptionY   No. Observations:                 4521
# Model:                          Logit   Df Residuals:                     4508
# Method:                           MLE   Df Model:                           12
# Date:                Wed, 30 Nov 2022   Pseudo R-squ.:                 0.02854
# Time:                        11:30:37   Log-Likelihood:                -1569.4
# converged:                       True   LL-Null:                       -1615.5
# Covariance Type:            nonrobust   LLR p-value:                 1.838e-14
# ...
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...
