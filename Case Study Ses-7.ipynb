# %%
import pandas as pd

# %%
from pickle import TRUE


data = pd.read_excel("Datasets//UV6397-XLS-ENG.xlsx", "Exhibit 2")
data

X = pd.read_excel("Datasets//UV6397-XLS-ENG.xlsx", "Exhibit 2")
X.drop("GIVE", axis = 1, inplace = True)
X
# Out:
#       ID                               School  SFR  LT20   GT50  GRAD   FRR
# 0      1             Arizona State University   24  0.42  0.160  0.59  0.81
# 1      2  Arkansas State University—Jonesboro   19  0.49  0.040  0.37  0.69
# 2      3                    Auburn University   18  0.24  0.170  0.66  0.87
# 3      4      United States Air Force Academy    8  0.74  0.001  0.81  0.88
# 4      5       United States Military Academy    8  0.95  0.000  0.86  0.92
# ..   ...                                  ...  ...   ...    ...   ...   ...
# 118  119               Wake Forest University   11  0.54  0.030  0.89  0.94
# 119  120          Washington State University   15  0.37  0.220  0.69  0.83
# 120  121             West Virginia University   23  0.32  0.190  0.59  0.80
# 121  122          Western Kentucky University   19  0.43  0.060  0.49  0.73
# 122  123          Western Michigan University   19  0.36  0.110  0.52  0.74
#
# [123 rows x 7 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
# OLS with only 1 X-Variable...

y = data["GIVE"]
x = data["GRAD"]
display (y)
display (x)
# Out:
# 0      0.08
# 1      0.11
# 2      0.31
# 3      0.11
# 4      0.28
#        ...
# 118    0.29
# 119    0.13
# 120    0.12
# 121    0.13
# 122    0.10
# Name: GIVE, Length: 123, dtype: float64
# 0      0.59
# 1      0.37
# 2      0.66
# 3      0.81
# 4      0.86
#        ...
# 118    0.89
# 119    0.69
# 120    0.59
# 121    0.49
# 122    0.52
# Name: GRAD, Length: 123, dtype: float64

# %%
import statsmodels.api as sm

X_constant = sm.add_constant(x)
lin_reg = sm.OLS(y, X_constant).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   GIVE   R-squared:                       0.465
# Model:                            OLS   Adj. R-squared:                  0.460
# Method:                 Least Squares   F-statistic:                     105.0
# Date:                Wed, 09 Nov 2022   Prob (F-statistic):           4.02e-18
# Time:                        10:53:40   Log-Likelihood:                 174.03
# No. Observations:                 123   AIC:                            -344.1
# Df Residuals:                     121   BIC:                            -338.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0672      0.021     -3.187      0.002      -0.109      -0.025
# ...

# %%
# Multiple Linear Regression with multi variate X...

y = data["GIVE"]
x = data[["GRAD", "SFR"]]
display(y)
display(x)
# Out:
# 0      0.08
# 1      0.11
# 2      0.31
# 3      0.11
# 4      0.28
#        ...
# 118    0.29
# 119    0.13
# 120    0.12
# 121    0.13
# 122    0.10
# Name: GIVE, Length: 123, dtype: float64
#      GRAD  SFR
# 0    0.59   24
# 1    0.37   19
# 2    0.66   18
# 3    0.81    8
# 4    0.86    8
# ..    ...  ...
# 118  0.89   11
# 119  0.69   15
# 120  0.59   23
# 121  0.49   19
# 122  0.52   19
#
# [123 rows x 2 columns]

# %%
# import statsmodels.api as sm
X_constant = sm.add_constant(x)
lin_reg = sm.OLS(y, X_constant).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   GIVE   R-squared:                       0.494
# Model:                            OLS   Adj. R-squared:                  0.486
# Method:                 Least Squares   F-statistic:                     58.65
# Date:                Wed, 09 Nov 2022   Prob (F-statistic):           1.71e-18
# Time:                        10:53:40   Log-Likelihood:                 177.54
# No. Observations:                 123   AIC:                            -349.1
# Df Residuals:                     120   BIC:                            -340.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0415      0.046      0.905      0.367      -0.049       0.132
# ...

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(x, y)

print(f'Coefficients: {lin_reg.coef_}')
print(f'Intercept: {lin_reg.intercept_}')
print(f'R^2 score: {lin_reg.score(x, y)}')
# Out:
# Coefficients: [ 0.26179295 -0.00385968]
# Intercept: 0.04147459391951781
# R^2 score: 0.49429813184103233

# %%
# Feature Selection...

def forward_selection(data, target, significance_level=0.05):
    initial_features = data.columns.tolist()
    best_features = []
    while (len(initial_features)>0):
        remaining_features = list(set(initial_features)-set(best_features))
        new_pval = pd.Series(index=remaining_features)
        for new_column in remaining_features:
            model = sm.OLS(target, sm.add_constant(data[best_features+[new_column]])).fit()
            new_pval[new_column] = model.pvalues[new_column]
        min_p_value = new_pval.min()
        if(min_p_value<significance_level):
            best_features.append(new_pval.idxmin())
        else:
            break
    return best_features

forward_selection(X,y)
# Out:
# C:\Users\Shreyansh Mohanty\AppData\Local\Temp\ipykernel_12840\955575173.py:8: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12840\955575173.py in <module>
#      17     return best_features
#      18
# ---> 19 forward_selection(X,y)
#
# ~\AppData\Local\Temp\ipykernel_12840\955575173.py in forward_selection(data, target, significance_level)
#       8         new_pval = pd.Series(index=remaining_features)
#       9         for new_column in remaining_features:
# ---> 10             model = sm.OLS(target, sm.add_constant(data[best_features+[new_column]])).fit()
#      11             new_pval[new_column] = model.pvalues[new_column]
# ...

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.linear_model import LinearRegression
sfs1 = SFS(LinearRegression(), k_features=(1, 5), forward=True, floating=False, cv=0)
sfs1.fit(X, y)

# %%
X_new = pd.DataFrame(data[["LT20", "GRAD"]])
X_new
# Out:
#      LT20  GRAD
# 0    0.42  0.59
# 1    0.49  0.37
# 2    0.24  0.66
# 3    0.74  0.81
# 4    0.95  0.86
# ..    ...   ...
# 118  0.54  0.89
# 119  0.37  0.69
# 120  0.32  0.59
# 121  0.43  0.49
# 122  0.36  0.52
#
# [123 rows x 2 columns]

# %%
X_constant = sm.add_constant(X_new)
lin_reg = sm.OLS(y, X_constant).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   GIVE   R-squared:                       0.522
# Model:                            OLS   Adj. R-squared:                  0.514
# Method:                 Least Squares   F-statistic:                     65.41
# Date:                Wed, 09 Nov 2022   Prob (F-statistic):           6.17e-20
# Time:                        11:24:09   Log-Likelihood:                 180.94
# No. Observations:                 123   AIC:                            -355.9
# Df Residuals:                     120   BIC:                            -347.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0928      0.021     -4.392      0.000      -0.135      -0.051
# ...

# %%
data['yhat'] = lin_reg.fittedvalues
data['resid'] = lin_reg.resid

sorted_data = data.sort_values(by=['resid'], ascending=True)
# sorted_data.head()
sorted_data
# Out:
#       ID                                School  SFR  LT20   GT50  GRAD   FRR  \
# 3      4       United States Air Force Academy    8  0.74  0.001  0.81  0.88
# 19    20     University of California—Berkeley   17  0.62  0.150  0.91  0.97
# 105  106  University of California—Los Angeles   16  0.52  0.220  0.90  0.97
# 84    85            San Diego State University   21  0.22  0.240  0.66  0.83
# 55    56   University of Maryland—College Park   18  0.35  0.160  0.81  0.94
# ..   ...                                   ...  ...   ...    ...   ...   ...
# 7      8                University of Arkansas   18  0.28  0.180  0.58  0.83
# 108  109     University of Southern California    9  0.63  0.110  0.89  0.97
# 72    73              University of Notre Dame   12  0.55  0.100  0.96  0.98
# 15    16                 University of Alabama   19  0.46  0.160  0.67  0.85
# 2      3                     Auburn University   18  0.24  0.170  0.66  0.87
#
#      GIVE      yhat     resid
# ...

# %%
# For question 4...

LT20_coeff = 0.1646
GRAD_coeff = 0.2606
const = -0.0928

LT20_val = 0.34
GRAD_val = 0.67

Predicted_giving_val = (LT20_coeff*LT20_val) + (GRAD_coeff*GRAD_val) + const
Predicted_giving_val
# Out:
# 0.137766
